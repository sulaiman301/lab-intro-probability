# %% [markdown]
# # Lab | Intro to Probability

# %% [markdown]
# **Objective**
#
# Welcome to this Intro to Probability lab, where we explore decision-making scenarios through the lens of probability and strategic analysis. In the business world, making informed decisions is crucial, especially when faced with uncertainties. This lab focuses on scenarios where probabilistic outcomes play a significant role in shaping strategies and outcomes. Students will engage in exercises that require assessing and choosing optimal paths based on data-driven insights. The goal is to enhance your skills by applying probability concepts to solve real-world problems.

# %%
# Create a new virtual environment named "probability_lab"
python -m venv probability_lab

# Activate the virtual environment
# Windows
probability_lab\Scripts\activate
# macOS/Linux
# source probability_lab/bin/activate
# Out:
#   Cell In[2], line 2
#     python -m venv probability_lab
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# #### Ironhack Airlines
#
# Often Airlines sell more tickets than they have seats available, this is called overbooking. Consider the following:
# - A plane has 450 seats.
# - Based on historical data we conclude that each individual passenger has a 3% chance of missing it's flight.
#
# If the Ironhack Airlines routinely sells 460 tickets, what is the chance that they have a seats for all passenger?

# %%
pip install scipy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 330.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 358.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.9 kB 518.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 405.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.5 MB 495.5 kB/s eta 0:01:30
# ...

# %%
pip install numpy scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import binom

# Parameters
n = 460  # number of trials (tickets sold)
p = 0.97  # probability of a passenger showing up
k = 450   #numbers of seats
# Calculate the cumulative probability for X <= 450
probability_all_have_seats = binom.cdf(k, n, p)
print(probability_all_have_seats)
# Out:
# 0.8844772466215423

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# #### Ironhack Call Center

# %% [markdown]
# Suppose a customer service representative at a call center is handling customer complaints. Consider the following:
# - The probability of successfully resolving a customer complaint on the first attempt is 0.3.
#
#
# What is the probability that the representative needs to make at least three attempts before successfully resolving a customer complaint?

# %%
from scipy.stats import geom

# Probability of success on each trial
p = 0.3

# Calculate the probability of needing at least 3 attempts (X >= 3)
# P(X >= 3) = 1 - P(X < 3) = 1 - (P(X = 1) + P(X = 2))
probability = 1 - geom.cdf(2, p)
probability
# Out:
# np.float64(0.49)

# %% [markdown]
# **Challenge 3**

# %% [markdown]
# #### Ironhack Website

# %% [markdown]
# Consider a scenario related to Ironhack website traffic. Where:
# - our website takes on average 500 visits per hour.
# - the website's server is designed to handle up to 550 vists per hour.
#
#
# What is the probability of the website server being overwhelmed?

# %%
from scipy.stats import poisson

# Parameters
lambda_ = 500  # average rate (visits per hour)

# Calculate the probability of more than 550 visits
probability = 1 - poisson.cdf(550, lambda_)
probability
# Out:
# np.float64(0.01289822084039205)

# %% [markdown]
# What is the probability of being overwhelmed at some point during a day? (consider 24hours)

# %%
# Probability of not being overwhelmed in one hour
p_not_overwhelmed_per_hour = poisson.cdf(550, lambda_)

# Probability of not being overwhelmed for 24 hours
p_not_overwhelmed_per_day = p_not_overwhelmed_per_hour ** 24

# Probability of being overwhelmed at least once in a day
probability_overwhelmed_per_day = 1 - p_not_overwhelmed_per_day
probability_overwhelmed_per_day
# Out:
# np.float64(0.2677043869515715)

# %% [markdown]
# **Challenge 4**

# %% [markdown]
# #### Ironhack Helpdesk

# %% [markdown]
# Consider a scenario related to the time between arrivals of customers at a service desk.
#
# On average, a customers arrives every 10minutes.
#
# What is the probability that the next customer will arrive within the next 5 minutes?

# %%
from scipy.stats import expon

# Parameter (rate)
lambda_ = 1 / 10  # average rate (1 customer per 10 minutes)

# Calculate the probability of a customer arriving within 5 minutes
probability = expon.cdf(5, scale=1/lambda_)
probability
# Out:
# np.float64(0.3934693402873666)

# %% [markdown]
# If there is no customer for 15minutes, employees can that a 5minutes break.
#
# What is the probability an employee taking a break?

# %%
# Calculate the probability of no customer arriving in 15 minutes
probability_no_arrival_15 = expon.cdf(15, scale=1/lambda_)

# Probability of an employee taking a break is the same as the probability of no customer arriving for 15 minutes
probability_no_arrival_15
# Out:
# np.float64(0.7768698398515702)

# %% [markdown]
# **Challenge 5**

# %% [markdown]
# The weights of a certain species of birds follow a normal distribution with a mean weight of 150 grams and a standard deviation of 10 grams.
#
# - If we randomly select a bird, what is the probability that its weight is between 140 and 160 grams?

# %%
from scipy.stats import norm

# Parameters
mu = 150  # mean
sigma = 10  # standard deviation

# Calculate the cumulative probabilities
p1 = norm.cdf(160, mu, sigma)
p2 = norm.cdf(140, mu, sigma)

# Probability of weight being between 140 and 160 grams
probability = p1 - p2
probability
# Out:
# np.float64(0.6826894921370859)

# %% [markdown]
# **Challenge 6**

# %% [markdown]
# If the lifetime (in hours) of a certain electronic component follows an exponential distribution with a mean lifetime of 50 hours, what is the probability that the component fails within the first 30 hours?

# %%
# Parameter (rate)
lambda_ = 1 / 50  # mean lifetime is 50 hours

# Calculate the probability of failure within 30 hours
probability = expon.cdf(30, scale=1/lambda_)
probability
# Out:
# np.float64(0.4511883639059735)
